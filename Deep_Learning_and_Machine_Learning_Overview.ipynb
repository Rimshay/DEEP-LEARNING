# %% [markdown]
# <a href="https://colab.research.google.com/github/Rimshay/DEEP-LEARNING/blob/main/Deep_Learning_and_Machine_Learning_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(np.random.randint(20,32, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df2 = pd.DataFrame(np.random.randint(33,39, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df3 = pd.DataFrame(np.random.randint(40,49, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df4 = pd.DataFrame(np.random.randint(50,59, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df5 = pd.DataFrame(np.random.randint(60,69, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df6 = pd.DataFrame(np.random.randint(70,79, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df7 = pd.DataFrame(np.random.randint(80,100, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])

df = pd.concat([df1,df2,df3,df4,df5,df6,df7])



df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  29  20  24  30  20
# 1  30  24  31  31  21
# 2  20  27  30  22  22
# 3  21  23  26  26  30
# 4  29  29  21  20  27

# %%
df['obtained'] = df.s1 + df.s2 + df.s3 + df.s4 + df.s5
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  29  20  24  30  20       123
# 1  30  24  31  31  21       137
# 2  20  27  30  22  22       121
# 3  21  23  26  26  30       126
# 4  29  29  21  20  27       126

# %%
df['percentage'] = df.obtained / 500 * 100
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage
# 0  29  20  24  30  20       123        24.6
# 1  30  24  31  31  21       137        27.4
# 2  20  27  30  22  22       121        24.2
# 3  21  23  26  26  30       126        25.2
# 4  29  29  21  20  27       126        25.2

# %% [markdown]
# ## **apply Symbolic AI, Classicial programming, tranditional programming, Rules Based programmin**
# Rules always define by programmer
# Rules + Input = Output

# %%
def grade(x):
    if x >= 80:
        return "A+"
    elif x >= 70:
        return "A"
    elif x >= 60:
        return "B"
    elif x >= 50:
        return "C"
    elif x >= 40:
        return "D"
    elif x >= 33:
        return "E"
    else:
        return "F"
    
df['Grade'] = df.percentage.apply(grade)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade
# 0  29  20  24  30  20       123        24.6     F
# 1  30  24  31  31  21       137        27.4     F
# 2  20  27  30  22  22       121        24.2     F
# 3  21  23  26  26  30       126        25.2     F
# 4  29  29  21  20  27       126        25.2     F

# %%
df.Grade.value_counts()
# Out:
# B     5000
# F     5000
# A     5000
# D     5000
# A+    5000
# C     5000
# E     5000
# Name: Grade, dtype: int64

# %%
df.corr().plot(kind='bar')

# %%
dic = {
    'F':7,
    "E":6,
    "D":5,
    "C":4,
    "B":3,
    "A":2,
    "A+":1
}
df['Grade1'] = df.Grade.map(dic)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade  Grade1
# 0  29  20  24  30  20       123        24.6     F       7
# 1  30  24  31  31  21       137        27.4     F       7
# 2  20  27  30  22  22       121        24.2     F       7
# 3  21  23  26  26  30       126        25.2     F       7
# 4  29  29  21  20  27       126        25.2     F       7

# %%
df.corr().plot(kind='bar')

# %% [markdown]
# **Find Grades(Rules) With Machine Learning**

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#split dataset in features and target variable
feature_cols = ['percentage']
X = df[feature_cols] # Features
y = df.Grade # Target variable

# %%
X.head(1)
# Out:
#    percentage
# 0        24.6

# %%
y.head(1)
# Out:
# 0    F
# Name: Grade, dtype: object

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# %%
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

# %%
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=tree, class_names=True,
              fontsize=8)
# Out:
# [Text(0.7777777777777778, 0.9166666666666666, 'X[0] <= 79.7\ngini = 0.857\nsamples = 24500\nvalue = [3520, 3543, 3516, 3469, 3505, 3494, 3453]\nclass = y[1]'),
#  Text(0.6666666666666666, 0.75, 'X[0] <= 69.0\ngini = 0.833\nsamples = 20957\nvalue = [3520, 0, 3516, 3469, 3505, 3494, 3453]\nclass = y[0]'),
#  Text(0.5555555555555556, 0.5833333333333334, 'X[0] <= 58.8\ngini = 0.8\nsamples = 17437\nvalue = [0, 0, 3516, 3469, 3505, 3494, 3453]\nclass = y[2]'),
#  Text(0.4444444444444444, 0.4166666666666667, 'X[0] <= 38.9\ngini = 0.75\nsamples = 13921\nvalue = [0, 0, 0, 3469, 3505, 3494, 3453]\nclass = y[4]'),
#  Text(0.2222222222222222, 0.25, 'X[0] <= 31.7\ngini = 0.5\nsamples = 6947\nvalue = [0, 0, 0, 0, 0, 3494, 3453]\nclass = y[5]'),
#  Text(0.1111111111111111, 0.08333333333333333, 'gini = 0.0\nsamples = 3453\nvalue = [0, 0, 0, 0, 0, 0, 3453]\nclass = y[6]'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 3494\nvalue = [0, 0, 0, 0, 0, 3494, 0]\nclass = y[5]'),
#  Text(0.6666666666666666, 0.25, 'X[0] <= 49.0\ngini = 0.5\nsamples = 6974\nvalue = [0, 0, 0, 3469, 3505, 0, 0]\nclass = y[4]'),
#  Text(0.5555555555555556, 0.08333333333333333, 'gini = 0.0\nsamples = 3505\nvalue = [0, 0, 0, 0, 3505, 0, 0]\nclass = y[4]'),
#  Text(0.7777777777777778, 0.08333333333333333, 'gini = 0.0\nsamples = 3469\nvalue = [0, 0, 0, 3469, 0, 0, 0]\nclass = y[3]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 3516\nvalue = [0, 0, 3516, 0, 0, 0, 0]\nclass = y[2]'),
#  Text(0.7777777777777778, 0.5833333333333334, 'gini = 0.0\nsamples = 3520\nvalue = [3520, 0, 0, 0, 0, 0, 0]\nclass = y[0]'),
#  Text(0.8888888888888888, 0.75, 'gini = 0.0\nsamples = 3543\nvalue = [0, 3543, 0, 0, 0, 0, 0]\nclass = y[1]')]

# %% [markdown]
# **Find Grades(Rules) with Deep Learning**
# input + Output = Rules

# %%
df1 = df[['s1', 's2', 's3', 's4', 's5', 'Grade']]
df1.head(2)
df1 = df1.sample(frac=1)
df1
# Out:
#       s1  s2  s3  s4  s5 Grade
# 2445  35  36  37  36  35     E
# 4518  23  30  22  24  29     F
# 4135  65  64  66  60  67     B
# 2470  63  62  60  61  61     B
# 1141  80  82  97  83  99    A+
# ...   ..  ..  ..  ..  ..   ...
# 1844  98  93  93  82  87    A+
# 436   78  71  72  74  72     A
# 88    33  38  33  36  34     E
# 3931  37  34  37  37  34     E
# 3032  62  60  60  63  64     B
#
# [35000 rows x 6 columns]

# %%
X = df1.loc[:, 's1':'s5']
X.head()
# Out:
#       s1  s2  s3  s4  s5
# 2445  35  36  37  36  35
# 4518  23  30  22  24  29
# 4135  65  64  66  60  67
# 2470  63  62  60  61  61
# 1141  80  82  97  83  99

# %%
Y = df1[['Grade']]
Y.head()
# Out:
#      Grade
# 2445     E
# 4518     F
# 4135     B
# 2470     B
# 1141    A+

# %% [markdown]
# **Vectorization to Y**
# one-hot-encoding

# %%
Y = df1['Grade']
Y = pd.get_dummies(Y)
Y.head()
# Out:
#       A  A+  B  C  D  E  F
# 2445  0   0  0  0  0  1  0
# 4518  0   0  0  0  0  0  1
# 4135  0   0  1  0  0  0  0
# 2470  0   0  1  0  0  0  0
# 1141  0   1  0  0  0  0  0

# %%
Y.drop_duplicates()
# Out:
#       A  A+  B  C  D  E  F
# 2445  0   0  0  0  0  1  0
# 4518  0   0  0  0  0  0  1
# 4135  0   0  1  0  0  0  0
# 1141  0   1  0  0  0  0  0
# 3231  0   0  0  1  0  0  0
# 4445  1   0  0  0  0  0  0
# 4863  0   0  0  0  1  0  0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %% [markdown]
# Create your model network structure
#
# first-layer (input_shape = X.no_of_columns)
# last-layers (output=Y.unique_labels(unique classes))
# activation = according to your problems (4.6)
# Dense(output, )

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(5,)))
model.add(Dense(16, activation='relu', input_shape=(5,)))
model.add(Dense(7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                192
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 839
# Trainable params: 839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# select loss function based on your problems

model.compile(optimizer=SGD(lr=0.002),
             loss='categorical_crossentropy',
             metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.fit(X, Y, epochs=30)
# Out:
# Epoch 1/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 1.9967 - acc: 0.1805
# Epoch 2/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7383 - acc: 0.2603
# Epoch 3/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.6546 - acc: 0.3186
# Epoch 4/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.5763 - acc: 0.3529
# Epoch 5/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.5097 - acc: 0.3857
# Epoch 6/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.4551 - acc: 0.4152
# Epoch 7/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.3945 - acc: 0.4490
# Epoch 8/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.3456 - acc: 0.4828
# Epoch 9/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.3010 - acc: 0.5138
# Epoch 10/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2603 - acc: 0.5403
# Epoch 11/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2287 - acc: 0.5551
# Epoch 12/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1905 - acc: 0.5701
# Epoch 13/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1549 - acc: 0.5843
# Epoch 14/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1264 - acc: 0.5951
# Epoch 15/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0822 - acc: 0.6106
# Epoch 16/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0547 - acc: 0.6154
# Epoch 17/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0206 - acc: 0.6272
# Epoch 18/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9863 - acc: 0.6436
# Epoch 19/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9566 - acc: 0.6515
# Epoch 20/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9257 - acc: 0.6663
# Epoch 21/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9026 - acc: 0.6748
# Epoch 22/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8779 - acc: 0.6871
# Epoch 23/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8515 - acc: 0.6982
# Epoch 24/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8260 - acc: 0.7076
# Epoch 25/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8082 - acc: 0.7153
# Epoch 26/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7883 - acc: 0.7282
# Epoch 27/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7700 - acc: 0.7371
# Epoch 28/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7503 - acc: 0.7437
# Epoch 29/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7337 - acc: 0.7509
# Epoch 30/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7186 - acc: 0.7623

# %%
df1 = pd.DataFrame(np.random.randint(20,100, size=(20,5)),
                  columns = ['s1','s2','s3','s4','s5'])

df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  59  72  63  34  21
# 1  55  95  35  83  67
# 2  46  47  87  30  27
# 3  81  88  36  83  26
# 4  46  47  32  20  81

# %%
Y.columns.take(np.argmax(model.predict([[90,98,95,97,95]]), axis=1))
# Out:
# Index(['A+'], dtype='object')

# %%
df1['predict']=Y.columns.take(np.argmax(model.predict(df1.loc[:,'s1':'s5']), axis=1))
df1
# Out:
#     s1  s2  s3  s4  s5 predict
# 0   59  72  63  34  21       F
# 1   55  95  35  83  67       F
# 2   46  47  87  30  27       F
# 3   81  88  36  83  26       F
# 4   46  47  32  20  81       F
# 5   74  79  36  69  76       F
# 6   95  79  36  58  94       F
# 7   24  36  48  82  83       F
# 8   31  76  46  29  29       F
# 9   73  26  50  27  49       F
# 10  61  56  47  36  37       F
# 11  91  78  70  76  92      A+
# 12  53  33  38  83  85       F
# 13  29  50  53  93  44       F
# 14  74  81  56  84  24       F
# 15  51  66  84  60  25       F
# 16  33  45  79  25  51       F
# 17  92  22  82  38  47       F
# 18  41  85  70  33  72       F
# 19  91  74  67  27  68       F

# %% [markdown]
# **Computer Vision problem**
# **load image from directory**
# apply Auto labels based on your folder names

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data_gen = ImageDataGenerator(rescale=1.0/255)

# %%
from zipfile import ZipFile
file_name = '/train.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
train_data = train_data_gen.flow_from_directory(
    "./train",
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Done
# Found 6 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam, SGD

# %%
150*150*3
# Out:
# 67500

# %%
model1 = Sequential()
model1.add(Flatten())
model1.add(Dense(5000, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
#Train Model1
hist = model1.fit(train_data, epochs=15)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 8s 8s/step - loss: 0.7224 - acc: 0.5000
# Epoch 2/15
# 1/1 [==============================] - 2s 2s/step - loss: 271.3299 - acc: 0.5000
# Epoch 3/15
# 1/1 [==============================] - 2s 2s/step - loss: 57.5604 - acc: 0.5000
# Epoch 4/15
# 1/1 [==============================] - 2s 2s/step - loss: 191.4944 - acc: 0.5000
# Epoch 5/15
# 1/1 [==============================] - 2s 2s/step - loss: 161.2812 - acc: 0.5000
# Epoch 6/15
# 1/1 [==============================] - 2s 2s/step - loss: 6.6545 - acc: 0.8333
# Epoch 7/15
# 1/1 [==============================] - 2s 2s/step - loss: 6.3885 - acc: 0.8333
# Epoch 8/15
# 1/1 [==============================] - 2s 2s/step - loss: 40.5690 - acc: 0.6667
# Epoch 9/15
# 1/1 [==============================] - 2s 2s/step - loss: 47.7643 - acc: 0.6667
# Epoch 10/15
# 1/1 [==============================] - 2s 2s/step - loss: 25.2089 - acc: 0.6667
# Epoch 11/15
# 1/1 [==============================] - 2s 2s/step - loss: 1.7529 - acc: 0.8333
# Epoch 12/15
# 1/1 [==============================] - 2s 2s/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 13/15
# 1/1 [==============================] - 2s 2s/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 14/15
# 1/1 [==============================] - 2s 2s/step - loss: 8.7967e-30 - acc: 1.0000
# Epoch 15/15
# 1/1 [==============================] - 2s 2s/step - loss: 4.4738 - acc: 0.8333

# %%
from zipfile import ZipFile
file_name = '/test.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Test Data
test_data = train_data_gen.flow_from_directory(
    "./test",
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Done
# Found 6 images belonging to 2 classes.

# %%
Y = model1.predict(test_data)
Y
# Out:
# array([[0.0000000e+00],
#        [1.0000000e+00],
#        [1.6807635e-09],
#        [1.9658834e-22],
#        [0.0000000e+00],
#        [0.0000000e+00]], dtype=float32)

# %%
np.where(Y>0, "Dog","Cat")
# Out:
# array([['Cat'],
#        ['Dog'],
#        ['Dog'],
#        ['Dog'],
#        ['Cat'],
#        ['Cat']], dtype='<U3')

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
img = image.load_img("./train/dog/2.jpg", target_size=(150,150))
x=image.img_to_array(img) / 255
x = x.reshape(1,-1)
model1.predict(x)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, None, None) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, None), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (None, 67500).
# array([[1.9658084e-22]], dtype=float32)
